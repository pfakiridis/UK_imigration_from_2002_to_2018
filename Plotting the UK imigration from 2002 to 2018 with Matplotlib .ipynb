# %%
#Importing the data set which has been acquired from the Department for Work & Pensions
#The dataset represents the new nationa insurance number registrations in the UK per nationality.

import pandas as pd

data = pd.read_excel('transpose.xls',sep=',\s+', delimiter=',', encoding="utf-8", skipinitialspace=True)
data.head(5)
# Out:
#    Year  Austria  Belgium  Denmark  Finland  France  Germany  Greece  Italy  \
# 0  2002      500      610      900      500    5630     3230    1300   4620
# 1  2003      460      600      880      500    5580     3380    1100   4560
# 2  2004      510      620      830      430    6240     3950    1100   4190
# 3  2005      660      760     1170      520    8640     5560    1450   6290
# 4  2006      720      940     1150      580   10560     6420    1610   7590
#
#    Luxembourg  Netherlands  Portugal  Ireland  Spain  Sweden  Estonia  \
# 0          20         1740      2980     2930   3610    1780       80
# 1          20         2050      3420     2960   3570    1590      120
# 2          20         2610      2990     2760   3140    1670      390
# 3          30         3330      3780     3570   4080    2530      680
# 4          40         3510      3870     3520   4280    2780      550
#
#    Czech_Republic  Slovakia  Hungary  Latvia  Lithuania  Poland  Slovenia  \
# ...

# %%
#Filling the missing values with 1. Where there is an NA, it means there was not a new registration of this nationality that year
#Although we choose to fill with 1 in order not to remove it completely, manipulating the data as least as possible.
data = data.fillna(1)

# %%
# The name of the groups of the EU countries are formed as per the UK Immigration Office. 
#The groups are formed according to the entry year of each country in the EU.
#For example Romania and Bulgaria were the last countries to join the EU in 2007 and formed the so called A2 group.

# %%
#Plotting different group of countries to ckech the distribution of the enw registrations


import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.figure(figsize=(12,9))
x1 = plt.plot(data.Year, data.Czech_Republic,label='Czech Republic', linewidth=4)
x2 = plt.plot(data.Year, data.Hungary, label='Hungary', linewidth=4)
x3 = plt.plot(data.Year, data.Estonia, label='Estonia', linewidth=4)
x4 = plt.plot(data.Year, data.Latvia, label='Latvia', linewidth=4)
x5 = plt.plot(data.Year, data.Lithuania, label='Lithuania', linewidth=4)
x6 = plt.plot(data.Year, data.Poland, label='Poland', linewidth=4)
x7 = plt.plot(data.Year, data.Slovakia, label='Slovakia', linewidth=4)
x8 = plt.plot(data.Year, data.Slovenia, label='Slovenia',linewidth=4, c="#40eb34")
x9 = plt.plot(data.Year, data.Cyprus, label='Cyprus',linewidth=4)
x10 = plt.plot(data.Year, data.Malta, label='Malta',linewidth=4, c='#eb34c6')

plt.xlabel('Year')
plt.ylabel('Number of New NINO Registrations')
plt.title('A8 Countries in Europe', fontdict={'fontweight':'bold', 'fontsize':18})
plt.legend(loc=2, prop={'size': 11})

plt.show()
#

plt.style.use('ggplot')
plt.figure(figsize=(12,9))
x1 = plt.plot(data.Year, data.Austria,label='Austria', linewidth=4)
x2 = plt.plot(data.Year, data.Belgium, label='Belgium', linewidth=4)
x3 = plt.plot(data.Year, data.Denmark, label='Denmark', linewidth=4)
x4 = plt.plot(data.Year, data.Finland, label='Finland', linewidth=4)
x5 = plt.plot(data.Year, data.France, label='France', linewidth=4)
x6 = plt.plot(data.Year, data.Germany, label='Germany', linewidth=4)
x7 = plt.plot(data.Year, data.Greece, label='Greece', linewidth=4)

plt.xlabel('Year')
plt.ylabel('Number of New NINO Registrations')
plt.title('A15 Countries in Europe (1st part)', fontdict={'fontweight':'bold', 'fontsize':18})
plt.legend(loc=2, prop={'size': 12})

plt.show()
#
plt.style.use('ggplot')
plt.figure(figsize=(12,9))
x1 = plt.plot(data.Year, data.Italy,label='Italy', linewidth=4)
x2 = plt.plot(data.Year, data.Luxembourg, label='Luxembourg', linewidth=4)
x3 = plt.plot(data.Year, data.Netherlands, label='Netherlands', linewidth=4)
x4 = plt.plot(data.Year, data.Portugal, label='Portugal', linewidth=4)
x5 = plt.plot(data.Year, data.Spain, label='Spain', linewidth=4)
x6 = plt.plot(data.Year, data.Sweden, label='Sweden', linewidth=4)
x8 = plt.plot(data.Year, data.Ireland, label='Ireland',linewidth=4)


plt.xlabel('Year')
plt.ylabel('Number of New NINO Registrations')
plt.title('A15 Countries in Europe (2nd part)', fontdict={'fontweight':'bold', 'fontsize':18})
plt.legend(loc=2, prop={'size': 12})

plt.show()
#
plt.style.use('ggplot')
plt.figure(figsize=(12,9))
x1 = plt.plot(data.Year, data.Romania,label='Romania', linewidth=4)
x2 = plt.plot(data.Year, data.Bulgaria, label='Bulgaria', linewidth=4)


plt.xlabel('Year')
plt.ylabel('Number of New NINO Registrations')
plt.title('A2 Countries in Europe', fontdict={'fontweight':'bold', 'fontsize':18})
plt.legend(loc=2, prop={'size': 12})

plt.show()
#
plt.style.use('ggplot')
plt.figure(figsize=(12,9))
x1 = plt.plot(data.Year, data.Australia,label='Australia', linewidth=4)
x2 = plt.plot(data.Year, data.Canada, label='Canada', linewidth=4)
x3 = plt.plot(data.Year, data.Ireland, label='Ireland', linewidth=4)
x4 = plt.plot(data.Year, data.New_Zealand, label='New Zealand', linewidth=4)
x5 = plt.plot(data.Year, data.Jamaica, label='Jamaica', linewidth=4)
x6 = plt.plot(data.Year, data.United_States, label='United States', linewidth=4)

plt.xlabel('Year')
plt.ylabel('Number of New NINO Registrations')
plt.title('English Speaking Countries', fontdict={'fontweight':'bold', 'fontsize':18})
plt.legend(loc=1, prop={'size': 12})

plt.show()

#
plt.style.use('ggplot')
plt.figure(figsize=(12,9))

x1 = plt.plot(data.Year, data.Russia,label='Russia', linewidth=4)
x2 = plt.plot(data.Year, data.China, label='China', linewidth=4)
x4 = plt.plot(data.Year, data.Turkey, label='Turkey', linewidth=4)
x5 = plt.plot(data.Year, data.India, label='India', linewidth=4)
x6 = plt.plot(data.Year, data.Pakistan, label='Pakistan', linewidth=4)
x7 = plt.plot(data.Year, data.Bangladesh, label='Bangladesh', linewidth=4)

plt.xlabel('Year')
plt.ylabel('Number of New NINO Registrations')
plt.title('Asian Countries', fontdict={'fontweight':'bold', 'fontsize':18})
plt.legend(loc=1, prop={'size': 12})

plt.show()
#
plt.style.use('ggplot')
plt.figure(figsize=(12,9))

x1 = plt.plot(data.Year, data.Nigeria,label='Nigeria', linewidth=4)
x2 = plt.plot(data.Year, data.Ethiopia, label='Ethiopia', linewidth=4)
x4 = plt.plot(data.Year, data.Congo, label='Congo', linewidth=4)
x5 = plt.plot(data.Year, data.Tanzania, label='Tanzania', linewidth=4)
x6 = plt.plot(data.Year, data.South_Africa, label='South Africa', linewidth=4)
x7 = plt.plot(data.Year, data.Kenya, label='Kenya', linewidth=4)
x8 = plt.plot(data.Year, data.Algeria, label='Algeria', linewidth=4)

plt.xlabel('Year')
plt.ylabel('Number of New NINO Registrations')
plt.title('African Countries', fontdict={'fontweight':'bold', 'fontsize':18})
plt.legend(loc=1, prop={'size': 12})

plt.show()

# %%
#The data has been transposed at this point because we need to test each year as a whole

df_tr = data.transpose()
df_tr = df_tr[1:]
df_tr.columns = new_header
df_tr.head(5)
# Out:
# Year     2002  2003  2004  2005   2006   2007   2008  2009   2010   2011  \
# Austria   500   460   510   660    720    800    800   520    790    680
# Belgium   610   600   620   760    940    980   1070   790   1180   1120
# Denmark   900   880   830  1170   1150    900   1100   760   1070   1030
# Finland   500   500   430   520    580    590    560   410    600    550
# France   5630  5580  6240  8640  10560  11950  13450  9040  13870  13580
#
# Year      2012   2013   2014   2015   2016   2017   2018
# Austria    649    633    750    802    806    661    662
# Belgium   1153   1259   1530   1575   1633   1415   1446
# Denmark    942   1023   1242   1154   1078    957    737
# Finland    540    533    749    767    740    638    688
# France   13299  13974  17277  16844  14683  13353  11591

# %%
# We filter the maximum number of registrations per year

df_tr.max(axis=0, skipna=None, level=None, numeric_only=None)
# Out:
# Year
# 2002    10140
# 2003    10950
# 2004    18990
# 2005    36970
# 2006    42930
# 2007    43780
# 2008    33130
# 2009    42390
# 2010    34830
# 2011    19680
# 2012    24974
# 2013    28345
# 2014    66931
# 2017    44532
# 2018    41998
# dtype: int64

# %%
# We convert the object into numeric values so we can get the sum valaue of each year/
newdata = df_tr.transform(pd.to_numeric, errors='coerce')

# %%
# We filter the country with the maximum number of registrations per year
most = newdata.idxmax(axis=0, skipna=True)
most
# Out:
# Year
# 2002    Australia
# 2003        India
# 2004       Poland
# 2005       Poland
# 2006       Poland
# 2007       Poland
# 2008       Poland
# 2009        India
# 2010        India
# 2011        India
# 2012        Spain
# 2013        Italy
# 2014      Romania
# 2015      Romania
# 2016      Romania
# 2017      Romania
# 2018      Romania
# dtype: object

# %%
#Importing numpy we create the arrays with the maximum values per year, the years and the countries.

import numpy as np

value = [10140,10950,18990,36970,42930,43780,33130,42390,34830,19680,24974,28345,66931,66810,63036,44532,41998]
n = ['Australia', 'India', 'Poland', 'Poland', 'Poland', 'Poland', 'Poland', 'India', 'India', 'India', 'Spain', 'Italy', 'Romania', 'Romania', 'Romania', 'Romania', 'Romania']
Year1 = ['2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018']


plt.style.use('ggplot') # Using the ggplot for better visualization
plt.figure(figsize=(14,10)) # Increase the size of the plot
plt.scatter(Year, value,s=100, c='r', linewidths=1, alpha=0.4) # Create the scatter plot with size 100 and color red
for i, txt in enumerate(n):
    plt.annotate(txt, (Year[i], value[i],)) #Importing the labels
plt.xticks(range(2002, 2019)) # Setting the x axes
plt.ylim((0,70000)) # Setting the y axes
plt.title('Countries with the most new registrations per year')
plt.xlabel('Year')
plt.ylabel('Number of New Registraions')
plt.show()

# %%
# Getting the sum of each new registration for each year

Total1 = newdata[2002].sum()
Total2 = newdata[2003].sum()
Total3 = newdata[2004].sum()
Total4 = newdata[2005].sum()
Total5 = newdata[2006].sum()
Total6 = newdata[2007].sum()
Total7 = newdata[2008].sum()
Total8 = newdata[2009].sum()
Total9 = newdata[2010].sum()
Total10 = newdata[2011].sum()
Total11 = newdata[2012].sum()
Total12 = newdata[2013].sum()
Total13 = newdata[2014].sum()
Total14 = newdata[2015].sum()
Total15 = newdata[2016].sum()
Total16 = newdata[2017].sum()
Total17 = newdata[2018].sum()

# %%
Total1,Total2,Total3,Total4,Total5,Total6,Total7,Total8,Total9,Total10,Total11,Total12,Total13,Total14,Total15,Total16,Total17
# Out:
# (149191,
#  157021,
#  169341,
#  235051,
#  240691,
#  272431,
#  275271,
#  248951,
#  300591,
#  249431,
#  225548,
#  242701,
#  333312,
#  317880.0,
#  290994.0,
#  234609,
#  238739)

# %%
# Creating two arrays for the bar chart. x the years and y the suma of new registrations per year

total = [149191,157021,169341,235051,240691,272431,275271,248951,300591,249431,225548,242701,333312,317880,290994,234609,238739]
Year1 = ['2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018']

plt.style.use('ggplot')
plt.figure(figsize=(14,8))

plt.bar(Year1,total, color='b')
plt.title('Total Number of New Registrations per Year')
plt.xlabel('Year')
plt.ylabel('Number of New Registrations')
plt.ylim((0,400000))


plt.show()
